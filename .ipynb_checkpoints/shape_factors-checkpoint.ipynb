# %% [markdown]
# # Shape factors
#
# * shape signature
# * **fourrier descriptor**
# * **zernike moments**
# * shape context

# %%
from os.path import join
from os import listdir
from mahotas.features import zernike_moments
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import warnings

warnings.filterwarnings("ignore")

plt.rc('image', cmap='gray')
plt.style.use('dark_background')

imgs = [
    cv.imread(join("baza", filename), 0)
    for filename in listdir("baza") if "Segmentation" in filename
]
img = imgs[0]

# %% [markdown]
# ## Zernike's moments
# ![zernike_math.png](attachment:zernike_math.png)

# %%
plt.imshow(img)

zernike_moments(img, radius=21)
# Out:
# array([3.18309886e-01, 1.09506086e-03, 2.73634826e-04, 2.93886316e-03,
#        2.19370899e-03, 2.36156429e-03, 3.49981429e-04, 4.64518012e-03,
#        2.74014286e-03, 3.31016634e-03, 3.63910285e-03, 4.58661246e-03,
#        2.62835408e-04, 5.94309289e-03, 3.81698371e-03, 5.85494572e-03,
#        4.47410522e-03, 4.99408422e-03, 6.29803603e-03, 6.98375442e-03,
#        5.82948546e-05, 6.62128137e-03, 4.85965776e-03, 7.02933235e-03,
#        4.46565239e-03])

# %% [markdown]
# ![zernike.png](attachment:zernike.png)

# %% [markdown]
# ### Catch 'Em All - [Tutorial](https://www.pyimagesearch.com/2014/04/07/building-pokedex-python-indexing-sprites-using-shape-descriptors-step-3-6/)
#
# ![find_pokemon.png](attachment:find_pokemon.png)

# %% [markdown]
# ![python-opencv-perspective-transform.jpeg](attachment:python-opencv-perspective-transform.jpeg)

# %% [markdown]
# ![pokemons.png](attachment:pokemons.png)

# %% [markdown]
# ![marowak-results.jpeg](attachment:marowak-results.jpeg)

# %% [markdown]
# ## Fourier descriptors

# %%
contour, _ = cv.findContours(img,
    cv.RETR_EXTERNAL,
    cv.CHAIN_APPROX_NONE
)
contour_array = contour[0][:, 0, :]
contour_complex = np.empty(contour_array.shape[:-1], dtype=complex)
contour_complex.real = contour_array[:, 0]
contour_complex.imag = contour_array[:, 1]
fourier_result = np.fft.fft(contour_complex)
fourier_result
# Out:
# array([ 1.52413900e+06+1152198.j        ,
#        -1.59030744e+04  -22714.93736286j,
#         1.45148749e+04  +24921.82370575j, ...,
#        -1.16100662e+03  -21688.88248639j,
#        -4.58560718e+03  -10321.7931089j ,
#        -1.16698330e+05 -581113.82636414j])

# %% [markdown]
# ![fourier.png](attachment:fourier.png)

# %% [markdown]
# ### Fourier descriptors reconstruction

# %%
degree = 18 * 5

descriptors = np.fft.fftshift(fourier_result)
center_index = len(descriptors) / 2

descriptors = descriptors[
              int(center_index - degree / 2):int(center_index + degree / 2)]
descriptors = np.fft.ifftshift(descriptors)

descriptor_in_use = descriptors
contour_reconstruct = np.fft.ifft(descriptor_in_use)
contour_reconstruct = np.array(
    [contour_reconstruct.real, contour_reconstruct.imag])
contour_reconstruct = np.transpose(contour_reconstruct)
contour_reconstruct = np.expand_dims(contour_reconstruct, axis=1)
if contour_reconstruct.min() < 0:
    contour_reconstruct -= contour_reconstruct.min()
x = np.argwhere(img == img.max()).max(axis=0).astype(np.float64)
contour_reconstruct *= x[::-1] / contour_reconstruct.max(axis=0)
contour_reconstruct = contour_reconstruct.astype(np.int32, copy=False)
black = np.zeros_like(img, np.uint8)

cv.drawContours(black, contour_reconstruct, -1, 255, thickness=4)
plt.figure(figsize=(10, 10))
plt.imshow(black)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %% [markdown]
# ## Pros and cons
#
# ### Zernike's moments
#
#  - Describes the internal structure of the object
#  - Resistant to scaling, rotation and noise
#  - Low dimensional representation
#
#  - Average cost of comparisons
#  - Very high cost of computing the signature
#
# ### Fourier descriptors
#
#  - Describes the contour of the outside
#  - invariant with respect to scaling, rotation and noise
#
#  - Average cost of comparisons
#  - Relatively high computational cost due to complex numbers
